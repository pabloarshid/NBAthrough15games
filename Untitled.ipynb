# %%
import numpy as np
import pandas as pd
import glob
import os

# %%
l = [pd.read_csv(filename, header = 0) for filename in glob.glob("/mnt/c/Users/umar_/Documents/Projects/Data/NBA/Through 15 games/*.csv")]
# Out:
#     Rk   G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  \
# 0    1   1  2003-10-29  18-303  CLE          @  SAC    L (-14)   1  42:00
# 1    2   2  2003-10-30  18-304  CLE          @  PHO     L (-9)   1  41:00
# 2    3   3  2003-11-01  18-306  CLE          @  POR    L (-19)   1  39:00
# 3    4   4  2003-11-05  18-310  CLE        NaN  DEN     L (-4)   1  41:00
# 4    5   5  2003-11-07  18-312  CLE          @  IND     L (-1)   1  44:00
# 5    6   6  2003-11-08  18-313  CLE        NaN  WAS    W (+13)   1  45:00
# 6    7   7  2003-11-10  18-315  CLE        NaN  NYK    W (+14)   1  34:00
# 7    8   8  2003-11-12  18-317  CLE          @  MIA     L (-5)   1  42:00
# 8    9   9  2003-11-14  18-319  CLE          @  BOS     L (-9)   1  35:00
# 9   10  10  2003-11-15  18-320  CLE        NaN  PHI     W (+3)   1  47:00
# 10  11  11  2003-11-18  18-323  CLE        NaN  LAC     W (+8)   1  39:00
# 11  12  12  2003-11-19  18-324  CLE          @  WAS    L (-11)   1  40:00
# ...

# %%
# Out:
# [    Rk   G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  \
#  0    1   1  2003-10-29  18-303  CLE          @  SAC    L (-14)   1  42:00
#  1    2   2  2003-10-30  18-304  CLE          @  PHO     L (-9)   1  41:00
#  2    3   3  2003-11-01  18-306  CLE          @  POR    L (-19)   1  39:00
#  3    4   4  2003-11-05  18-310  CLE        NaN  DEN     L (-4)   1  41:00
#  4    5   5  2003-11-07  18-312  CLE          @  IND     L (-1)   1  44:00
#  5    6   6  2003-11-08  18-313  CLE        NaN  WAS    W (+13)   1  45:00
#  6    7   7  2003-11-10  18-315  CLE        NaN  NYK    W (+14)   1  34:00
#  7    8   8  2003-11-12  18-317  CLE          @  MIA     L (-5)   1  42:00
#  8    9   9  2003-11-14  18-319  CLE          @  BOS     L (-9)   1  35:00
#  9   10  10  2003-11-15  18-320  CLE        NaN  PHI     W (+3)   1  47:00
#  10  11  11  2003-11-18  18-323  CLE        NaN  LAC     W (+8)   1  39:00
# ...
